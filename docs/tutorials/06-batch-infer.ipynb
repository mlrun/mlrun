# %% [markdown]
# (batch-infer-drift-tutor)=
# # Batch inference and drift detection
#
# This tutorial leverages a function from the [MLRun Function Hub](https://www.mlrun.org/hub/) to perform [batch inference](https://www.mlrun.org/hub/functions/master/batch_inference_v2/) using a logged model and a new prediction dataset. The function also calculates data drift by comparing the new prediction dataset with the original training set.
#
# Make sure you have reviewed the basics in MLRun [**Quick Start Tutorial**](01-mlrun-basics.ipynb).

# %% [markdown]
# Tutorial steps:
# - [**Set up a project**](#set-up-a-project)
# - [**View the data**](#view-the-data)
# - [**Log the model with training data**](#log-the-model-with-training-data)
# - [**Import and run the batch inference function**](#import-and-run-the-batch-inference-function)
# - [**Predictions and drift status**](#predictions-and-drift-status)
# - [**Examining the drift results in the dashboard**](#examining-the-drift-results-in-the-dashboard)
# - [**Next steps**](#next-steps)

# %% [markdown]
# ## MLRun installation and configuration
#
# Before running this notebook make sure `mlrun` is installed and that you have configured the access to the MLRun service.

# %%
# !/User/align_mlrun.sh
# Out:
# Both server & client are aligned (1.7.0rc28).

# %% [markdown]
# <a id="setup-project"></a>
# ## Set up a project
#
# First, import the dependencies and create an [MLRun project](https://docs.mlrun.org/en/stable/projects/create-project.html). The project contains all of your models, functions, datasets, etc.:

# %%
import mlrun
import pandas as pd
from mlrun.datastore.datastore_profile import DatastoreProfileV3io
# Out:
# > 2025-03-19 15:14:01,533 [warning] Failed resolving version info. Ignoring and using defaults
# > 2025-03-19 15:14:04,949 [warning] Server or client version is unstable. Assuming compatible: {"client_version":"0.0.0+unstable","server_version":"1.8.0"}

# %%
project = mlrun.get_or_create_project("tutorial", context="./", user_project=True)
# Out:
# > 2025-03-19 15:14:05,147 [info] Loading project from path: {"path":"./","project_name":"tutorial","user_project":true}
# > 2025-03-19 15:14:19,911 [info] Project loaded successfully: {"path":"./","project_name":"tutorial-iguazio","stored_in_db":true}

# %% [markdown]
# ```{admonition} Note
# This tutorial does not focus on training a model. Instead, it starts with a trained model and its corresponding training and prediction dataset.
# ```
#
# You'll use the following model files and datasets to perform the batch prediction. The model is a [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) from sklearn and the datasets are in `parquet` format.

# %%
# Choose the correct model to avoid pickle warnings
import sys

suffix = (
    mlrun.__version__.split("-")[0].replace(".", "_")
    if sys.version_info[1] > 7
    else "3.7"
)

model_path = mlrun.get_sample_path(f"models/batch-predict/model-{suffix}.pkl")
training_set_path = mlrun.get_sample_path("data/batch-predict/training_set.parquet")
prediction_set_path = mlrun.get_sample_path("data/batch-predict/prediction_set.parquet")
drifted_prediction_set_path = mlrun.get_sample_path(
    "data/batch-predict/drifted_prediction_set.parquet"
)

# %% [markdown]
# <a id="view-data"></a>
# ## View the data
#
# The training data has 20 numerical features and a binary (0,1) label:

# %%
pd.read_parquet(training_set_path).head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   0.572754   0.171079   0.403080   0.955429   0.272039   0.360277
# 1   0.623733  -0.149823  -1.410537  -0.729388  -1.996337  -1.213348
# 2   0.814168  -0.221412   0.020822   1.066718  -0.573164   0.067838
# 3   1.062279  -0.966309   0.341471  -0.737059   1.460671   0.367851
# 4   0.195755   0.576332  -0.260496   0.841489   0.398269  -0.717972
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_11  feature_12  \
# 0  -0.995429   0.437239   0.991556   0.010004  ...    0.112194   -0.319256
# 1   1.461307   1.187854  -1.790926  -0.981600  ...    0.428653   -0.503820
# 2   0.923045   0.338146   0.981413   1.481757  ...   -1.052559   -0.241873
# 3  -0.435336   0.445308  -0.655663  -0.196220  ...    0.641017    0.099059
# 4   0.810550  -1.058326   0.368610   0.606007  ...    0.195267    0.876144
#
#    feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  \
# 0   -0.392631   -0.290766    1.265054    1.037082   -1.200076    0.820992
# 1   -0.798035    2.038105   -3.080463    0.408561    1.647116   -0.838553
# 2   -1.232272   -0.010758    0.806800    0.661162    0.589018    0.522137
# 3    1.902592   -1.024929    0.030703   -0.198751   -0.342009   -1.286865
# 4    0.151615    0.094867    0.627353   -0.389023    0.662846   -0.857000
#
#    feature_19  label
# 0    0.834868      0
# 1    0.680983      1
# 2   -0.924624      0
# 3   -1.118373      1
# 4    1.091218      1
#
# [5 rows x 21 columns]

# %% [markdown]
# **The prediction data has 20 numerical features, but no label - this is what you will predict:**

# %%
pd.read_parquet(prediction_set_path).head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -2.059506  -1.314291   2.721516  -2.132869  -0.693963   0.376643
# 1  -1.190382   0.891571   3.726070   0.673870  -0.252565  -0.729156
# 2  -0.996384  -0.099537   3.421476   0.162771  -1.143458  -1.026791
# 3  -0.289976  -1.680019   3.126478  -0.704451  -1.149112   1.174962
# 4  -0.294866   1.044919   2.924139   0.814049  -1.455054  -0.270432
#
#    feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  \
# 0   3.017790   3.876329  -1.294736   0.030773    0.401491    2.775699
# 1   2.646563   4.782729   0.318952  -0.781567    1.473632    1.101721
# 2   2.114702   2.517553  -0.154620  -0.465423   -1.723025    1.729386
# 3   2.860341   3.753661  -0.326119   2.128411   -0.508000    2.328688
# 4   3.380195   2.339669   1.029101  -1.171018   -1.459395    1.283565
#
#    feature_12  feature_13  feature_14  feature_15  feature_16  feature_17  \
# 0    2.361580    0.173441    0.879510    1.141007    4.608280   -0.518388
# 1    3.723400   -0.466867   -0.056224    3.344701    0.194332    0.463992
# 2    2.820340   -1.041428   -0.331871    2.909172    2.138613   -0.046252
# 3    3.397321   -0.932060   -1.442370    2.058517    3.881936    2.090635
# 4    0.677006   -2.147444   -0.494150    3.222041    6.219348   -1.914110
#
#    feature_18  feature_19
# 0    0.129690    2.794967
# 1    0.292268    4.665876
# 2   -0.732631    4.716266
# 3   -0.045832    4.197315
# 4    0.317786    4.143443

# %% [markdown]
# <a id="log-model"></a>
# ## Log the model with training data
#
# Next, log the model using MLRun experiment tracking. This is usually done in a training pipeline, but you can also bring in your pre-trained models from other sources. See [Working with data and model artifacts](https://docs.mlrun.org/en/stable/training/working-with-data-and-model-artifacts.html) and [Automated experiment tracking](https://docs.mlrun.org/en/stable/concepts/auto-logging-mlops.html) for more information.
#
# In this example, you are logging a training set with the model for future comparison, however you can also directly pass in your training set to the batch prediction function.

# %%
model_artifact = project.log_model(
    key="model",
    model_file=model_path,
    framework="sklearn",
    training_set=pd.read_parquet(training_set_path),
    label_column="label",
)

# %%
# the model artifact unique URI
model_artifact.uri
# Out:
# 'store://models/tutorial-iguazio/model#0@21542518-ba99-4bdf-8c9d-0a5295d4f44e^1b6df53a8916f6e981bd15f81039098aa440c203'

# %% [markdown]
# ## Enabling model monitoring
#
# The MLRun's model monitoring service includes built-in model monitoring and reporting capabilities.<br>
# Visit MLRun's {ref}`model-monitoring-des` to read more and check out the {ref}`realtime-monitor-drift-tutor`.
#
# Modifying controller frequency with `base_period` parameter to 1 minute allows to see monitoring results faster, by default, its value is 10 minutes.

# %%
tsdb_profile = DatastoreProfileV3io(name="v3io-tsdb-profile")
project.register_datastore_profile(tsdb_profile)

stream_profile = DatastoreProfileV3io(
    name="v3io-stream-profile",
    v3io_access_key=mlrun.mlconf.get_v3io_access_key(),
)
project.register_datastore_profile(stream_profile)

# %%
project.set_model_monitoring_credentials(
    tsdb_profile_name=tsdb_profile.name,
    stream_profile_name=stream_profile.name,
)

# %%
project.enable_model_monitoring(
    base_period=1,
    wait_for_deployment=True,
    deploy_histogram_data_drift_app=True,
)
# Out:
# > 2025-03-19 15:14:32,620 [warning] enable_model_monitoring: 'base_period' < 10 minutes is not supported in production environments: {"project":"tutorial-iguazio"}
# 2025-03-19 15:14:35  (info) Deploying function
# 2025-03-19 15:14:35  (info) Building
# 2025-03-19 15:14:36  (info) Staging files and preparing base images
# 2025-03-19 15:14:36  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2025-03-19 15:14:36  (info) Building processor image
# 2025-03-19 15:17:01  (info) Build complete
# 2025-03-19 15:17:21  (info) Function deploy complete
# 2025-03-19 15:14:32  (info) Deploying function
# 2025-03-19 15:14:32  (info) Building
# 2025-03-19 15:14:33  (info) Staging files and preparing base images
# 2025-03-19 15:14:33  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2025-03-19 15:14:33  (info) Building processor image
# 2025-03-19 15:16:56  (info) Build complete
# 2025-03-19 15:17:35  (info) Function deploy complete
# 2025-03-19 15:14:34  (info) Deploying function
# 2025-03-19 15:14:34  (info) Building
# 2025-03-19 15:14:34  (info) Staging files and preparing base images
# 2025-03-19 15:14:34  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2025-03-19 15:14:34  (info) Building processor image
# 2025-03-19 15:16:52  (info) Build complete
# 2025-03-19 15:17:14  (info) Function deploy complete
# 2025-03-19 15:14:37  (info) Deploying function
# 2025-03-19 15:14:37  (info) Building
# 2025-03-19 15:14:38  (info) Staging files and preparing base images
# 2025-03-19 15:14:38  (warn) Using user provided base image, runtime interpreter version is provided by the base image
# 2025-03-19 15:14:38  (info) Building processor image
# 2025-03-19 15:16:41  (info) Build complete
# 2025-03-19 15:17:08  (info) Function deploy complete

# %% [markdown]
# <a id="run"></a>
# ## Import and run the batch inference function
#
# Next, import the [batch inference](https://www.mlrun.org/hub/functions/master/batch_inference_v2/) function from the [MLRun Function Hub](https://www.mlrun.org/hub/):

# %%
fn = mlrun.import_function("hub://batch_inference_v2")

# %% [markdown]
# ### Run batch inference
#
# Finally, perform the batch prediction by passing in your model and datasets.
#
# Including `perform_drift_analysis` saves the batch to be analyzed by the project's model monitoring applications, and a new model endpoint record is generated.
# [Model endpoint](https://docs.mlrun.org/en/stable/model-monitoring/index.html#model-and-model-monitoring-endpoints) is a unique MLRun entity that includes statistics and important details about your model and function.
# You can perform the drift analysis on an existing model endpoint, but you need to make sure that you don't mix unrelated datasets that could affect the final drift analysis process.
# In general, it's recommended to perform the drift analysis on a new model endpoint to avoid possible analysis conflicts.
#
# See the corresponding [batch inference example notebook](https://github.com/mlrun/functions/blob/master/batch_inference_v2/batch_inference_v2.ipynb) for an exhaustive list of other parameters that are supported:

# %%
run = project.run_function(
    fn,
    inputs={
        "dataset": prediction_set_path,
    },
    params={
        "model_path": model_artifact.uri,
        "perform_drift_analysis": True,
    },
)
# Out:
# > 2025-03-19 15:18:00,645 [info] Storing function: {"db":"http://mlrun-api:8080","name":"batch-inference-v2-infer","uid":"7819ed1f65fe4112a30e10ee14255200"}
# > 2025-03-19 15:18:01,116 [info] Job is running in the background, pod: batch-inference-v2-infer-vv4xw
# > 2025-03-19 15:18:09,643 [info] Loading model...
# Trying to unpickle estimator DecisionTreeClassifier from version 1.5.1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# > 2025-03-19 15:18:13,495 [info] Loading data...
# > 2025-03-19 15:18:15,993 [info] Calculating prediction...
# > 2025-03-19 15:18:15,998 [info] Logging result set (x | prediction)...
# > 2025-03-19 15:18:16,196 [info] Performing drift analysis...
# > 2025-03-19 15:18:17,775 [info] Bumping model endpoint last request time (EP without serving): {"bumped_last_request":"2025-03-19T15:20:16.426808+00:00","current_request":"2025-03-19T15:18:16.426808+00:00","endpoint_id":"5030a685ebb1465ba7419196020535e9","last_request":"2025-03-19T15:18:16.226219+00:00","project":"tutorial-iguazio"}
# > 2025-03-19 15:18:17,775 [info] Patching model endpoint: {"attributes_keys":["last_request"],"model_endpoint":{"kind":"model-endpoint","metadata":{"created":null,"endpoint_type":1,"labels":{},"name":"batch-infer","project":"tutorial-iguazio","tag":null,"uid":"5030a685ebb1465ba7419196020535e9","updated":null},"spec":{"children":[],"children_uids":[],"feature_names":[],"feature_stats":{},"function_name":"batch-inference-v2","function_tag":null,"function_uri":"","label_names":[],"model_class":"","model_name":"","model_path":"","model_tags":[],"model_uri":"","monitoring_feature_set_uri":""},"status":{"avg_latency":null,"current_stats":{},"current_stats_timestamp":null,"drift_measures":{},"drift_measures_timestamp":null,"error_count":0,"first_request":null,"last_request":"2025-03-19T15:20:16.426808+00:00","monitoring_mode":"disabled","result_status":-1,"sampling_percentage":100,"state":"unknown"}}}
# > 2025-03-19 15:18:17,823 [info] Updating model endpoint done: {"model_endpoint_uid":"5030a685ebb1465ba7419196020535e9","status_code":200}
# > 2025-03-19 15:18:17,905 [info] To track results use the CLI: {"info_cmd":"mlrun get run 7819ed1f65fe4112a30e10ee14255200 -p tutorial-iguazio","logs_cmd":"mlrun logs 7819ed1f65fe4112a30e10ee14255200 -p tutorial-iguazio"}
# > 2025-03-19 15:18:17,905 [info] Or click for UI: {"ui_url":"https://dashboard.default-tenant.app.vmdev67.lab.iguazeng.com/mlprojects/tutorial-iguazio/jobs/monitor-jobs/batch-inference-v2-infer/7819ed1f65fe4112a30e10ee14255200/overview"}
# > 2025-03-19 15:18:17,906 [info] Run execution finished: {"name":"batch-inference-v2-infer","status":"completed"}
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#
#   // Get the base URL of the current notebook
#   var baseUrl = window.location.origin;
#
#   // Construct the full URL
#   var fullUrl = new URL(el.title, baseUrl).href;
#
#   document.querySelector(panelName + "-title").innerHTML = fullUrl
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (fullUrl.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", fullUrl);
#   oReq.send();
#
#
#   //iframe.src = fullUrl;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>end</th>
#       <th>state</th>
#       <th>kind</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>tutorial-iguazio</td>
#       <td><div title="7819ed1f65fe4112a30e10ee14255200"><a href="https://dashboard.default-tenant.app.vmdev67.lab.iguazeng.com/mlprojects/tutorial-iguazio/jobs/monitor/7819ed1f65fe4112a30e10ee14255200/overview" target="_blank" >...14255200</a></div></td>
#       <td>0</td>
#       <td>Mar 19 15:18:09</td>
#       <td>2025-03-19 15:18:17+00:00</td>
#       <td>completed</td>
#       <td>run</td>
#       <td>batch-inference-v2-infer</td>
#       <td><div class="dictlist">v3io_user=iguazio</div><div class="dictlist">kind=job</div><div class="dictlist">owner=iguazio</div><div class="dictlist">mlrun/client_version=0.0.0+unstable</div><div class="dictlist">mlrun/client_python_version=3.9.18</div><div class="dictlist">host=batch-inference-v2-infer-vv4xw</div></td>
#       <td><div title="https://s3.wasabisys.com/iguazio/data/batch-predict/prediction_set.parquet">dataset</div></td>
#       <td><div class="dictlist">model_path=store://models/tutorial-iguazio/model#0@21542518-ba99-4bdf-8c9d-0a5295d4f44e^1b6df53a8916f6e981bd15f81039098aa440c203</div><div class="dictlist">perform_drift_analysis=True</div></td>
#       <td><div class="dictlist">batch_id=22304e6085e6e5bbcdfd3f549ae8474eee011013c5cd07110d8303a0</div></td>
#       <td><div title="v3io:///projects/tutorial-iguazio/artifacts/batch-inference-v2-infer/0/prediction.parquet">prediction</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resulte59e1b56-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resulte59e1b56-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resulte59e1b56" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resulte59e1b56-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.vmdev67.lab.iguazeng.com/mlprojects/tutorial-iguazio/jobs/monitor-jobs/batch-inference-v2-infer/7819ed1f65fe4112a30e10ee14255200/overview" target="_blank">click here</a> to open in UI</b>
# > 2025-03-19 15:18:23,560 [info] Run execution finished: {"name":"batch-inference-v2-infer","status":"completed"}

# %% [markdown]
# <a id="predictions-and-drift-status"></a>
# ## Predictions and drift status

# %% [markdown]
# These are the batch predictions on the prediction set from the model:

# %%
run.artifact("prediction").as_df().head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -2.059506  -1.314291   2.721516  -2.132869  -0.693963   0.376643
# 1  -1.190382   0.891571   3.726070   0.673870  -0.252565  -0.729156
# 2  -0.996384  -0.099537   3.421476   0.162771  -1.143458  -1.026791
# 3  -0.289976  -1.680019   3.126478  -0.704451  -1.149112   1.174962
# 4  -0.294866   1.044919   2.924139   0.814049  -1.455054  -0.270432
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_11  feature_12  \
# 0   3.017790   3.876329  -1.294736   0.030773  ...    2.775699    2.361580
# 1   2.646563   4.782729   0.318952  -0.781567  ...    1.101721    3.723400
# 2   2.114702   2.517553  -0.154620  -0.465423  ...    1.729386    2.820340
# 3   2.860341   3.753661  -0.326119   2.128411  ...    2.328688    3.397321
# 4   3.380195   2.339669   1.029101  -1.171018  ...    1.283565    0.677006
#
#    feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  \
# 0    0.173441    0.879510    1.141007    4.608280   -0.518388    0.129690
# 1   -0.466867   -0.056224    3.344701    0.194332    0.463992    0.292268
# 2   -1.041428   -0.331871    2.909172    2.138613   -0.046252   -0.732631
# 3   -0.932060   -1.442370    2.058517    3.881936    2.090635   -0.045832
# 4   -2.147444   -0.494150    3.222041    6.219348   -1.914110    0.317786
#
#    feature_19  label
# 0    2.794967      0
# 1    4.665876      1
# 2    4.716266      0
# 3    4.197315      0
# 4    4.143443      0
#
# [5 rows x 21 columns]

# %% [markdown]
# Enabling model monitoring application with default `deploy_histogram_data_drift_app` provide additional plots like; `drift_table_plot` that compares the drift between the training data and prediction data per feature and `features_drift_results` to show each feature drift score.

# %%
import time
import json

# Wait two minutes safety interval for the controller to finish triggering the apps and write to databases.
time.sleep(120)

json.loads(project.get_artifact("features_drift_results").to_dataitem().get())
# Out:
# {'feature_0': 1.0,
#  'feature_1': 1.0,
#  'feature_2': 1.0,
#  'feature_3': 1.0,
#  'feature_4': 1.0,
#  'feature_5': 1.0,
#  'feature_6': 1.0,
#  'feature_7': 1.0,
#  'feature_8': 1.0,
#  'feature_9': 1.0,
#  'feature_10': 0.0425670356,
#  'feature_11': 0.8245431701,
#  'feature_12': 0.8207787616,
#  'feature_13': 0.0425972466,
#  'feature_14': 0.0463647238,
#  'feature_15': 0.7452075684,
#  'feature_16': 0.8207622589,
#  'feature_17': 0.0360778575,
#  'feature_18': 0.0444373261,
#  'feature_19': 0.8138698698,
#  'label': 0.5965504049}

# %% [markdown]
# Finally, you also get a numerical drift metric and boolean flag denoting whether or not data drift is detected:

# %%
import mlrun.model_monitoring.api
import yaml

endpoint = mlrun.model_monitoring.api.get_or_create_model_endpoint(
    project=project.name,
    model_endpoint_name="batch-infer",
    function_name="batch-inference-v2",
    feature_analysis=True,
)
print(f"Drift detected : {'no' if endpoint.status.result_status=='0' else 'yes'}")
print(
    f"Drift metrics :\n{yaml.dump(endpoint.status.drift_measures, default_flow_style=False)}"
)
# Out:
# Drift detected : yes
# Drift metrics :
# feature_0:
#   hellinger: 0.0335736819532152
#   kld: 0.00800914608038614
#   tvd: 0.022800000000000008
# feature_1:
#   hellinger: 0.04630145403326306
#   kld: 0.015136099233745426
#   tvd: 0.04359999999999999
# feature_10:
#   hellinger: 0.04473407115760209
#   kld: 0.016107595511326803
#   tvd: 0.04039999999999998
# feature_11:
#   hellinger: 0.8058863402254881
#   kld: 8.207418374913285
#   tvd: 0.8432000000000001
# feature_12:
#   hellinger: 0.807957523155725
#   kld: 8.540674048943202
#   tvd: 0.8336
# feature_13:
#   hellinger: 0.04519449310948248
#   kld: 0.014349562433429235
#   tvd: 0.039999999999999994
# feature_14:
#   hellinger: 0.05472944756352956
#   kld: 0.022306296862012256
#   tvd: 0.038
# feature_15:
#   hellinger: 0.746815136758792
#   kld: 7.493164579525918
#   tvd: 0.7435999999999999
# feature_16:
#   hellinger: 0.8003245177804857
#   kld: 8.097063905853084
#   tvd: 0.8412
# feature_17:
#   hellinger: 0.038955714991485355
#   kld: 0.010677448229097126
#   tvd: 0.03320000000000001
# feature_18:
#   hellinger: 0.04647465218765195
#   kld: 0.015894237456896394
#   tvd: 0.04240000000000001
# feature_19:
#   hellinger: 0.7993397396310428
#   kld: 7.613455815187319
#   tvd: 0.8283999999999999
# feature_2:
#   hellinger: 0.7900559843329186
#   kld: 7.404702739661648
#   tvd: 0.8264
# feature_3:
#   hellinger: 0.04913963802970058
#   kld: 0.017331946342858506
#   tvd: 0.038400000000000004
# feature_4:
#   hellinger: 0.04691128230500036
#   kld: 0.016764727973826582
#   tvd: 0.03879999999999999
# feature_5:
#   hellinger: 0.05408439667581095
#   kld: 0.021480434076905017
#   tvd: 0.05039999999999999
# feature_6:
#   hellinger: 0.7926084404395208
#   kld: 7.631668338501731
#   tvd: 0.8400000000000002
# feature_7:
#   hellinger: 0.7949812589747411
#   kld: 7.75413745622129
#   tvd: 0.8368000000000001
# feature_8:
#   hellinger: 0.0397202637470994
#   kld: 0.011098991721351776
#   tvd: 0.03880000000000001
# feature_9:
#   hellinger: 0.046567270093498515
#   kld: 0.0142817874641359
#   tvd: 0.0432
# hellinger_mean: 0.3594333477892465
# kld_mean: 3.347361348174046
# label:
#   hellinger: 0.6637449964281223
#   kld: 7.368864779461525
#   tvd: 0.4952
# tvd_mean: 0.3599238095238095

# %% [markdown]
# ## Examining the drift results in the dashboard
# <a id="iguazio-platform"></a>

# %% [markdown]
# This section reviews the main charts and statistics that can be found on the platform dashboard. See {ref}`model-monitoring-des` to learn more about the available model monitoring features and how to use them.

# %% [markdown]
# Before analyzing the results in the visual dashboards, run another batch infer job, but this time with drifted data, to get a drifted result. The drift decision rule is the value per-feature mean of the [Total Variance Distance (TVD) and Hellinger distance](https://docs.mlrun.org/en/stable/model-monitoring/index.html#model-monitoring-applications) scores.<br>
# In the histogram-data-drift application, the "Drift detected" threshold is 0.7 and the "Drift suspected" threshold is 0.3

# %%
run = project.run_function(
    fn,
    inputs={
        "dataset": drifted_prediction_set_path,
    },
    params={
        "model_path": model_artifact.uri,
        "perform_drift_analysis": True,
        "model_endpoint_name": "drifted-model-endpoint",
    },
)
# Out:
# > 2025-03-19 15:42:23,770 [info] Storing function: {"db":"http://mlrun-api:8080","name":"batch-inference-v2-infer","uid":"4db3fbc7d191452dbf67621ab4ea8417"}
# > 2025-03-19 15:42:24,150 [info] Job is running in the background, pod: batch-inference-v2-infer-blwhw
# > 2025-03-19 15:42:32,877 [info] Loading model...
# Trying to unpickle estimator DecisionTreeClassifier from version 1.5.1 when using version 1.5.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
# > 2025-03-19 15:42:36,765 [info] Loading data...
# > 2025-03-19 15:42:38,386 [info] Calculating prediction...
# > 2025-03-19 15:42:38,390 [info] Logging result set (x | prediction)...
# > 2025-03-19 15:42:38,581 [info] Performing drift analysis...
# > 2025-03-19 15:42:40,042 [info] Bumping model endpoint last request time (EP without serving): {"bumped_last_request":"2025-03-19T15:44:38.787663+00:00","current_request":"2025-03-19T15:42:38.787663+00:00","endpoint_id":"2ed998f676f74dc8b5b67182bf0a4de9","last_request":"2025-03-19T15:42:38.603633+00:00","project":"tutorial-iguazio"}
# > 2025-03-19 15:42:40,042 [info] Patching model endpoint: {"attributes_keys":["last_request"],"model_endpoint":{"kind":"model-endpoint","metadata":{"created":null,"endpoint_type":1,"labels":{},"name":"drifted-model-endpoint","project":"tutorial-iguazio","tag":null,"uid":"2ed998f676f74dc8b5b67182bf0a4de9","updated":null},"spec":{"children":[],"children_uids":[],"feature_names":[],"feature_stats":{},"function_name":"batch-inference-v2","function_tag":null,"function_uri":"","label_names":[],"model_class":"","model_name":"","model_path":"","model_tags":[],"model_uri":"","monitoring_feature_set_uri":""},"status":{"avg_latency":null,"current_stats":{},"current_stats_timestamp":null,"drift_measures":{},"drift_measures_timestamp":null,"error_count":0,"first_request":null,"last_request":"2025-03-19T15:44:38.787663+00:00","monitoring_mode":"disabled","result_status":-1,"sampling_percentage":100,"state":"unknown"}}}
# > 2025-03-19 15:42:40,070 [info] Updating model endpoint done: {"model_endpoint_uid":"2ed998f676f74dc8b5b67182bf0a4de9","status_code":200}
# > 2025-03-19 15:42:40,130 [info] To track results use the CLI: {"info_cmd":"mlrun get run 4db3fbc7d191452dbf67621ab4ea8417 -p tutorial-iguazio","logs_cmd":"mlrun logs 4db3fbc7d191452dbf67621ab4ea8417 -p tutorial-iguazio"}
# > 2025-03-19 15:42:40,130 [info] Or click for UI: {"ui_url":"https://dashboard.default-tenant.app.vmdev67.lab.iguazeng.com/mlprojects/tutorial-iguazio/jobs/monitor-jobs/batch-inference-v2-infer/4db3fbc7d191452dbf67621ab4ea8417/overview"}
# > 2025-03-19 15:42:40,131 [info] Run execution finished: {"name":"batch-inference-v2-infer","status":"completed"}
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#
#   // Get the base URL of the current notebook
#   var baseUrl = window.location.origin;
#
#   // Construct the full URL
#   var fullUrl = new URL(el.title, baseUrl).href;
#
#   document.querySelector(panelName + "-title").innerHTML = fullUrl
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (fullUrl.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", fullUrl);
#   oReq.send();
#
#
#   //iframe.src = fullUrl;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>end</th>
#       <th>state</th>
#       <th>kind</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>tutorial-iguazio</td>
#       <td><div title="4db3fbc7d191452dbf67621ab4ea8417"><a href="https://dashboard.default-tenant.app.vmdev67.lab.iguazeng.com/mlprojects/tutorial-iguazio/jobs/monitor/4db3fbc7d191452dbf67621ab4ea8417/overview" target="_blank" >...b4ea8417</a></div></td>
#       <td>0</td>
#       <td>Mar 19 15:42:32</td>
#       <td>2025-03-19 15:42:40+00:00</td>
#       <td>completed</td>
#       <td>run</td>
#       <td>batch-inference-v2-infer</td>
#       <td><div class="dictlist">v3io_user=iguazio</div><div class="dictlist">kind=job</div><div class="dictlist">owner=iguazio</div><div class="dictlist">mlrun/client_version=0.0.0+unstable</div><div class="dictlist">mlrun/client_python_version=3.9.18</div><div class="dictlist">host=batch-inference-v2-infer-blwhw</div></td>
#       <td><div title="https://s3.wasabisys.com/iguazio/data/batch-predict/drifted_prediction_set.parquet">dataset</div></td>
#       <td><div class="dictlist">model_path=store://models/tutorial-iguazio/model#0@21542518-ba99-4bdf-8c9d-0a5295d4f44e^1b6df53a8916f6e981bd15f81039098aa440c203</div><div class="dictlist">perform_drift_analysis=True</div><div class="dictlist">model_endpoint_name=drifted-model-endpoint</div></td>
#       <td><div class="dictlist">batch_id=ed0369302db2ae3738b9263d654d89800fffd77708dbbdd9dc977399</div></td>
#       <td><div title="v3io:///projects/tutorial-iguazio/artifacts/batch-inference-v2-infer/0/prediction.parquet">prediction</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result8de7f123-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result8de7f123-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result8de7f123" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result8de7f123-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.vmdev67.lab.iguazeng.com/mlprojects/tutorial-iguazio/jobs/monitor-jobs/batch-inference-v2-infer/4db3fbc7d191452dbf67621ab4ea8417/overview" target="_blank">click here</a> to open in UI</b>
# > 2025-03-19 15:42:44,690 [info] Run execution finished: {"name":"batch-inference-v2-infer","status":"completed"}

# %% [markdown]
# Now you can observe the drift result:

# %%
time.sleep(120)

endpoint = mlrun.model_monitoring.api.get_or_create_model_endpoint(
    project=project.name,
    model_endpoint_name="drifted-model-endpoint",
    function_name="batch-inference-v2",
    feature_analysis=True,
)
print(f"Drift detected : {'no' if endpoint.status.result_status=='0' else 'yes'}")
print(
    f"Drift metrics :\n{yaml.dump(endpoint.status.drift_measures, default_flow_style=False)}"
)
# Out:
# Drift detected : yes
# Drift metrics :
# feature_0:
#   hellinger: 1.0
#   kld: 15.947831766111843
#   tvd: 1.0
# feature_1:
#   hellinger: 1.0
#   kld: 15.942530740720345
#   tvd: 1.0
# feature_10:
#   hellinger: 0.04473407115760209
#   kld: 0.016107595511326803
#   tvd: 0.04039999999999998
# feature_11:
#   hellinger: 0.8058863402254881
#   kld: 8.207418374913285
#   tvd: 0.8432000000000001
# feature_12:
#   hellinger: 0.807957523155725
#   kld: 8.540674048943202
#   tvd: 0.8336
# feature_13:
#   hellinger: 0.04519449310948248
#   kld: 0.014349562433429235
#   tvd: 0.039999999999999994
# feature_14:
#   hellinger: 0.05472944756352956
#   kld: 0.022306296862012256
#   tvd: 0.038
# feature_15:
#   hellinger: 0.746815136758792
#   kld: 7.493164579525918
#   tvd: 0.7435999999999999
# feature_16:
#   hellinger: 0.8003245177804857
#   kld: 8.097063905853084
#   tvd: 0.8412
# feature_17:
#   hellinger: 0.038955714991485355
#   kld: 0.010677448229097126
#   tvd: 0.03320000000000001
# feature_18:
#   hellinger: 0.04647465218765195
#   kld: 0.015894237456896394
#   tvd: 0.04240000000000001
# feature_19:
#   hellinger: 0.7993397396310428
#   kld: 7.613455815187319
#   tvd: 0.8283999999999999
# feature_2:
#   hellinger: 1.0
#   kld: 15.954249871425905
#   tvd: 1.0
# feature_3:
#   hellinger: 1.0
#   kld: 16.040915135106705
#   tvd: 1.0
# feature_4:
#   hellinger: 1.0
#   kld: 16.070032712370534
#   tvd: 1.0
# feature_5:
#   hellinger: 1.0
#   kld: 15.85304618612945
#   tvd: 1.0
# feature_6:
#   hellinger: 1.0
#   kld: 15.892588362525856
#   tvd: 1.0
# feature_7:
#   hellinger: 1.0
#   kld: 15.9013904377493
#   tvd: 1.0
# feature_8:
#   hellinger: 1.0
#   kld: 15.935217661233798
#   tvd: 1.0
# feature_9:
#   hellinger: 1.0
#   kld: 15.965031755202496
#   tvd: 1.0
# hellinger_mean: 0.7089672593481341
# kld_mean: 9.89546171616421
# label:
#   hellinger: 0.6979008097495295
#   kld: 8.270749545956615
#   tvd: 0.4952
# tvd_mean: 0.7037714285714287

# %% [markdown]
# ### Model Endpoints

# %% [markdown]
# In the Projects page > [Model endpoint summary list](https://docs.mlrun.org/en/stable/model-monitoring/monitoring-models.html#model-endpoints-summary-list), you can see the new two model endpoints, including their drift status:

# %% [markdown]
# ![Model Endpoints Summary List](./_static/images/batch_infer_list_model_endpoints.png)

# %% [markdown]
# You can zoom into one of the model endpoints to get an [overview](https://docs.mlrun.org/en/stable/model-monitoring/monitoring-models.html#model-endpoints-overview) about the selected endpoint, including the calculated statistical drift metrics:

# %% [markdown]
# ![Model Endpoint Overview](./_static/images/batch_infer_overview_model_endpoint.png)

# %% [markdown]
# Press [Features Analysis](https://docs.mlrun.org/en/stable/model-monitoring/monitoring-models.html#model-endpoints-features-analysis) to see details of the drift analysis in a table format with each feature in the selected model on its own line, including the predicted label:

# %% [markdown]
# ![Model Endpoint Feature Analysis](./_static/images/batch_infer_feature_analysis.png)

# %% [markdown]
# ## Next steps
# In a production setting, you probably want to incorporate this as part of a larger pipeline or application.
#
# For example, if you use this function for the prediction capabilities, you can pass the `prediction` output as the input to another pipeline step, store it in an external location like S3, or send to an application or user.
#
# If you use this function for the drift detection capabilities, you can use the `drift_status` and `drift_metrics` outputs to automate further pipeline steps, send a notification, or kick off a re-training pipeline.

# %% [markdown]
# ## Done!
#
# Congratulations! You've completed Part 6 of the MLRun getting-started tutorial.
# You may want to review the additional tutorials:
# - [Add MLOps to existing code](07-add-mlops-to-code)
# - [Feature store example (stocks)](https://docs.mlrun.org/en/stable/feature-store/basic-demo.html)
# - [MLflow tracker](mlflow.ipynb)
