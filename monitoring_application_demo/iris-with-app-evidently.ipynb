# %%
# !pip uninstall -y mlrun
# !pip install git+https://github.com/davesh0812/mlrun.git@feature/monitoring-batch-02
# Out:
# Found existing installation: mlrun 0.0.0+unstable
# Uninstalling mlrun-0.0.0+unstable:
#   Successfully uninstalled mlrun-0.0.0+unstable
# Collecting git+https://github.com/davesh0812/mlrun.git@feature/monitoring-batch-02
#   Cloning https://github.com/davesh0812/mlrun.git (to revision feature/monitoring-batch-02) to /tmp/pip-req-build-c4ce2pvi
#   Running command git clone --filter=blob:none --quiet https://github.com/davesh0812/mlrun.git /tmp/pip-req-build-c4ce2pvi
#   Running command git checkout -b feature/monitoring-batch-02 --track origin/feature/monitoring-batch-02
#   Switched to a new branch 'feature/monitoring-batch-02'
#   Branch 'feature/monitoring-batch-02' set up to track remote branch 'feature/monitoring-batch-02' from 'origin'.
#   Resolved https://github.com/davesh0812/mlrun.git to commit 85903bdc69fa412861b3a3d1533c5a9c393ad613
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fsspec<2023.7,>=2023.1 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (2023.6.0)
# Requirement already satisfied: GitPython>=3.1.30,~=3.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (3.1.31)
# Requirement already satisfied: semver~=2.13 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (2.13.0)
# Requirement already satisfied: kfp<1.8.14,~=1.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.8.13)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.21.6)
# Requirement already satisfied: inflection~=0.5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.5.1)
# Requirement already satisfied: distributed~=2021.11.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (2021.11.2)
# Requirement already satisfied: scikit-learn in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.2.2)
# Requirement already satisfied: storey~=1.5.5 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.5.5)
# Requirement already satisfied: kubernetes~=12.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (12.0.1)
# Requirement already satisfied: setuptools~=65.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (65.6.3)
# Requirement already satisfied: anyio~=3.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (3.6.2)
# Requirement already satisfied: aiohttp-retry~=2.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (2.8.3)
# Requirement already satisfied: pandas<1.5.0,~=1.2 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.3.5)
# Requirement already satisfied: nuclio-jupyter~=0.9.11 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.9.11)
# Requirement already satisfied: deprecated~=1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.2.13)
# Requirement already satisfied: click~=8.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (8.0.4)
# Requirement already satisfied: jinja2~=3.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (3.1.2)
# Requirement already satisfied: alembic~=1.9 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.10.3)
# Requirement already satisfied: mergedeep~=1.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.3.4)
# Requirement already satisfied: urllib3<1.27,>=1.26.9 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.26.15)
# Requirement already satisfied: tabulate~=0.8.6 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.8.10)
# Requirement already satisfied: v3io-frames~=0.10.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.10.5)
# Requirement already satisfied: orjson<3.8.12,~=3.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (3.8.10)
# Requirement already satisfied: python-dotenv~=0.17.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.17.1)
# Requirement already satisfied: ipython~=8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (8.11.0)
# Requirement already satisfied: dependency-injector~=4.41 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (4.41.0)
# Requirement already satisfied: nest-asyncio~=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.5.6)
# Requirement already satisfied: aiohttp~=3.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (3.8.4)
# Requirement already satisfied: v3iofs~=0.1.15 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.1.15)
# Requirement already satisfied: dask~=2021.11.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (2021.11.2)
# Requirement already satisfied: pyarrow<12,>=10.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (10.0.1)
# Requirement already satisfied: chardet<4.0,>=3.0.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (3.0.4)
# Requirement already satisfied: v3io~=0.5.21 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (0.5.21)
# Requirement already satisfied: deepdiff~=5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (5.8.1)
# Requirement already satisfied: pydantic>=1.10.8,~=1.10 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (1.10.12)
# Requirement already satisfied: pyyaml~=5.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (5.4.1)
# Requirement already satisfied: requests~=2.22 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from mlrun==0.0.0+unstable) (2.28.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (3.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from aiohttp~=3.8->mlrun==0.0.0+unstable) (1.8.2)
# Requirement already satisfied: SQLAlchemy>=1.3.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from alembic~=1.9->mlrun==0.0.0+unstable) (1.4.47)
# Requirement already satisfied: typing-extensions>=4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from alembic~=1.9->mlrun==0.0.0+unstable) (4.5.0)
# Requirement already satisfied: Mako in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from alembic~=1.9->mlrun==0.0.0+unstable) (1.2.4)
# Requirement already satisfied: idna>=2.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from anyio~=3.5->mlrun==0.0.0+unstable) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from anyio~=3.5->mlrun==0.0.0+unstable) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun==0.0.0+unstable) (2.2.1)
# Requirement already satisfied: toolz>=0.8.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun==0.0.0+unstable) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun==0.0.0+unstable) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dask~=2021.11.2->mlrun==0.0.0+unstable) (21.3)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from deepdiff~=5.0->mlrun==0.0.0+unstable) (4.1.0)
# Requirement already satisfied: six<=1.16.0,>=1.7.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from dependency-injector~=4.41->mlrun==0.0.0+unstable) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from deprecated~=1.2->mlrun==0.0.0+unstable) (1.15.0)
# Requirement already satisfied: tornado>=6.0.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun==0.0.0+unstable) (6.3)
# Requirement already satisfied: psutil>=5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun==0.0.0+unstable) (5.9.5)
# Requirement already satisfied: tblib>=1.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun==0.0.0+unstable) (1.7.0)
# Requirement already satisfied: msgpack>=0.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun==0.0.0+unstable) (1.0.5)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun==0.0.0+unstable) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from distributed~=2021.11.2->mlrun==0.0.0+unstable) (3.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from GitPython>=3.1.30,~=3.1->mlrun==0.0.0+unstable) (4.0.10)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (3.0.38)
# Requirement already satisfied: stack-data in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (0.6.2)
# Requirement already satisfied: decorator in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (0.18.2)
# Requirement already satisfied: traitlets>=5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (5.9.0)
# Requirement already satisfied: backcall in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (0.2.0)
# Requirement already satisfied: pickleshare in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (2.15.1)
# Requirement already satisfied: matplotlib-inline in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from ipython~=8.0->mlrun==0.0.0+unstable) (0.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jinja2~=3.1->mlrun==0.0.0+unstable) (2.1.2)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (3.2.0)
# Requirement already satisfied: strip-hints<1,>=0.1.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.1.10)
# Requirement already satisfied: typer<1.0,>=0.3.2 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.9.0)
# Requirement already satisfied: absl-py<2,>=0.9 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (1.4.0)
# Requirement already satisfied: google-cloud-storage<2,>=1.20.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (1.44.0)
# Requirement already satisfied: kfp-pipeline-spec<0.2.0,>=0.1.14 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.1.16)
# Requirement already satisfied: protobuf<4,>=3.13.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (3.19.6)
# Requirement already satisfied: fire<1,>=0.3.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.5.0)
# Requirement already satisfied: google-api-python-client<2,>=1.7.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (1.12.11)
# Requirement already satisfied: kfp-server-api<2.0.0,>=1.1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (1.8.5)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.10.1)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.15)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (2.10.2)
# Requirement already satisfied: google-auth<2,>=1.6.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (1.35.0)
# Requirement already satisfied: uritemplate<4,>=3.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (3.0.1)
# Requirement already satisfied: certifi>=14.05.14 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun==0.0.0+unstable) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun==0.0.0+unstable) (2.8.2)
# Requirement already satisfied: requests-oauthlib in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun==0.0.0+unstable) (1.3.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from kubernetes~=12.0->mlrun==0.0.0+unstable) (1.5.1)
# Requirement already satisfied: notebook>=6.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (6.5.4)
# Requirement already satisfied: nbconvert>=6.4.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (7.3.1)
# Requirement already satisfied: boto3>=1.9 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (1.17.106)
# Requirement already satisfied: pytz>=2017.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from pandas<1.5.0,~=1.2->mlrun==0.0.0+unstable) (2023.3)
# Requirement already satisfied: xxhash>=1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from storey~=1.5.5->mlrun==0.0.0+unstable) (3.2.0)
# Requirement already satisfied: nuclio-sdk>=0.5.3 in /User/.pythonlibs/mlrun-extended/lib/python3.9/site-packages (from storey~=1.5.5->mlrun==0.0.0+unstable) (0.5.6)
# Requirement already satisfied: ujson>=3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io~=0.5.21->mlrun==0.0.0+unstable) (5.7.0)
# Requirement already satisfied: future>=0.18.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io~=0.5.21->mlrun==0.0.0+unstable) (0.18.3)
# Requirement already satisfied: googleapis-common-protos>=1.5.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io-frames~=0.10.4->mlrun==0.0.0+unstable) (1.59.0)
# Requirement already satisfied: grpcio!=1.34.0,<1.49,>=1.30 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io-frames~=0.10.4->mlrun==0.0.0+unstable) (1.48.2)
# Requirement already satisfied: grpcio-tools!=1.34.0,<1.49,>=1.30 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from v3io-frames~=0.10.4->mlrun==0.0.0+unstable) (1.48.2)
# Requirement already satisfied: scipy>=1.3.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn->mlrun==0.0.0+unstable) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn->mlrun==0.0.0+unstable) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn->mlrun==0.0.0+unstable) (3.1.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from boto3>=1.9->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.106 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from boto3>=1.9->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (1.20.106)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from boto3>=1.9->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.10.0)
# Requirement already satisfied: termcolor in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from fire<1,>=0.3.1->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (2.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.30,~=3.1->mlrun==0.0.0+unstable) (5.0.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-api-python-client<2,>=1.7.8->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-api-python-client<2,>=1.7.8->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.1.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-auth<2,>=1.6.1->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-auth<2,>=1.6.1->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-auth<2,>=1.6.1->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (4.9)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-storage<2,>=1.20.0->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (2.4.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-cloud-storage<2,>=1.20.0->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (2.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jedi>=0.16->ipython~=8.0->mlrun==0.0.0+unstable) (0.8.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jsonschema<4,>=3.0.1->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.19.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (1.5.0)
# Requirement already satisfied: tinycss2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (4.12.2)
# Requirement already satisfied: nbformat>=5.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (5.8.0)
# Requirement already satisfied: defusedxml in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.7.1)
# Requirement already satisfied: bleach in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (6.0.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (6.5.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (2.0.5)
# Requirement already satisfied: jupyter-core>=4.7 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (5.3.0)
# Requirement already satisfied: jupyterlab-pygments in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.7.3)
# Requirement already satisfied: argon2-cffi in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.17.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (8.2.0)
# Requirement already satisfied: ipython-genutils in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (25.0.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.5.5)
# Requirement already satisfied: ipykernel in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (5.5.5)
# Requirement already satisfied: prometheus-client in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.16.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (1.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from packaging>=20.0->dask~=2021.11.2->mlrun==0.0.0+unstable) (3.0.9)
# Requirement already satisfied: locket in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from partd>=0.3.10->dask~=2021.11.2->mlrun==0.0.0+unstable) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from pexpect>4.3->ipython~=8.0->mlrun==0.0.0+unstable) (0.7.0)
# Requirement already satisfied: wcwidth in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython~=8.0->mlrun==0.0.0+unstable) (0.2.6)
# Requirement already satisfied: greenlet!=0.4.17 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from SQLAlchemy>=1.3.0->alembic~=1.9->mlrun==0.0.0+unstable) (2.0.2)
# Requirement already satisfied: wheel in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from strip-hints<1,>=0.1.8->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.38.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from requests-oauthlib->kubernetes~=12.0->mlrun==0.0.0+unstable) (3.2.2)
# Requirement already satisfied: pure-eval in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from stack-data->ipython~=8.0->mlrun==0.0.0+unstable) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from stack-data->ipython~=8.0->mlrun==0.0.0+unstable) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from stack-data->ipython~=8.0->mlrun==0.0.0+unstable) (1.2.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage<2,>=1.20.0->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-core>=4.7->nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (3.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.2.2)
# Requirement already satisfied: fastjsonschema in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from nbformat>=5.1->nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (2.16.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.1->kfp<1.8.14,~=1.8.0->mlrun==0.0.0+unstable) (0.4.8)
# Requirement already satisfied: argon2-cffi-bindings in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from argon2-cffi->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (2.4.1)
# Requirement already satisfied: webencodings in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from bleach->nbconvert>=6.4.5->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.5.1)
# Requirement already satisfied: jupyter-server-terminals in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.4.4)
# Requirement already satisfied: jupyter-events>=0.4.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.6.3)
# Requirement already satisfied: cffi>=1.0.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (1.15.1)
# Requirement already satisfied: pycparser in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (2.21)
# Requirement already satisfied: rfc3339-validator in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4->nuclio-jupyter~=0.9.11->mlrun==0.0.0+unstable) (0.1.1)
# WARNING: jsonschema 3.2.0 does not provide the extra 'format-nongpl'
# Building wheels for collected packages: mlrun
#   Building wheel for mlrun (pyproject.toml) ... done
#   Created wheel for mlrun: filename=mlrun-0.0.0+unstable-py3-none-any.whl size=1354819 sha256=84eba7cb5de5b72d6e22e5a76728f7cf729db2d4441120a6a2e7f13781d0d481
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xbi5fmtt/wheels/bb/cf/52/b4ea0d8e9412dd7977b0d5f6333a1992ea8057fdf603881a98
# Successfully built mlrun
# Installing collected packages: mlrun
# Successfully installed mlrun-0.0.0+unstable

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /conda/envs/mlrun-extended/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /conda/envs/mlrun-extended/lib/python3.9/site-packages (from scikit-learn) (1.22.4)

# %%
# %config Completer.use_jedi = False
import os
import pandas as pd
from sklearn.datasets import load_iris
import mlrun
from mlrun import import_function, get_dataitem, get_or_create_project

project_name = "new-iris-app-ev-v28"
project = get_or_create_project(project_name, context="./")
# Out:
# > 2023-09-06 11:22:10,676 [warning] Failed resolving version info. Ignoring and using defaults
# > 2023-09-06 11:22:15,343 [warning] Server or client version is unstable. Assuming compatible: {'server_version': '1.5.0+monitoring-batch-02', 'client_version': '0.0.0+unstable'}
# > 2023-09-06 11:22:15,538 [info] Loading project from path: {'project_name': 'new-iris-app-ev-v28', 'path': './'}
# > 2023-09-06 11:22:31,520 [info] Project loaded successfully: {'project_name': 'new-iris-app-ev-v28', 'path': './', 'stored_in_db': True}

# %%
# Download the pre-trained Iris model
# get_dataitem("https://s3.wasabisys.com/iguazio/models/iris/model.pkl").download("model.pkl")

iris = load_iris()
train_set = pd.DataFrame(
    iris["data"],
    columns=["sepal_length_cm", "sepal_width_cm", "petal_length_cm", "petal_width_cm"],
)

model_name = "RandomForestClassifier"

# Log the model through the projects API so that it is available through the feature store API
# TODO: log training dataset
project.log_model(model_name, model_file="model.pkl", training_set=train_set)

# %% [markdown]
# # Evidently Project Creation

# %%
import datetime

from sklearn import datasets

from evidently.metrics import ColumnDriftMetric
from evidently.metrics import ColumnSummaryMetric
from evidently.metrics import DatasetDriftMetric
from evidently.metrics import DatasetMissingValuesMetric
from evidently.report import Report
from evidently.test_preset import DataDriftTestPreset
from evidently.test_suite import TestSuite
from evidently.ui.dashboards import CounterAgg
from evidently.ui.dashboards import DashboardPanelCounter
from evidently.ui.dashboards import DashboardPanelPlot
from evidently.ui.dashboards import PanelValue
from evidently.ui.dashboards import PlotType
from evidently.ui.dashboards import ReportFilter
from evidently.ui.remote import RemoteWorkspace
from evidently.ui.workspace import Workspace
from evidently.ui.workspace import WorkspaceBase

adult_data = datasets.fetch_openml(name="adult", version=2, as_frame="auto")
adult = adult_data.frame

adult_ref = adult[~adult.education.isin(["Some-college", "HS-grad", "Bachelors"])]
adult_cur = adult[adult.education.isin(["Some-college", "HS-grad", "Bachelors"])]

WORKSPACE = os.path.abspath(
    f"/v3io/projects/{project_name}/artifacts/evidently_workspace"
)


YOUR_PROJECT_NAME = "iris monitoring"
YOUR_PROJECT_DESCRIPTION = "Test project using iris dataset."


def create_project(workspace: WorkspaceBase):
    project = workspace.create_project(YOUR_PROJECT_NAME)
    project.description = YOUR_PROJECT_DESCRIPTION
    project.dashboard.add_panel(
        DashboardPanelCounter(
            filter=ReportFilter(metadata_values={}, tag_values=[]),
            agg=CounterAgg.NONE,
            title="Income Dataset (iris)",
        )
    )
    project.dashboard.add_panel(
        DashboardPanelCounter(
            title="Model Calls",
            filter=ReportFilter(metadata_values={}, tag_values=[]),
            value=PanelValue(
                metric_id="DatasetMissingValuesMetric",
                field_path=DatasetMissingValuesMetric.fields.current.number_of_rows,
                legend="count",
            ),
            text="count",
            agg=CounterAgg.SUM,
            size=1,
        )
    )
    project.dashboard.add_panel(
        DashboardPanelCounter(
            title="Share of Drifted Features",
            filter=ReportFilter(metadata_values={}, tag_values=[]),
            value=PanelValue(
                metric_id="DatasetDriftMetric",
                field_path="share_of_drifted_columns",
                legend="share",
            ),
            text="share",
            agg=CounterAgg.LAST,
            size=1,
        )
    )
    project.dashboard.add_panel(
        DashboardPanelPlot(
            title="Dataset Quality",
            filter=ReportFilter(metadata_values={}, tag_values=[]),
            values=[
                PanelValue(
                    metric_id="DatasetDriftMetric",
                    field_path="share_of_drifted_columns",
                    legend="Drift Share",
                ),
                PanelValue(
                    metric_id="DatasetMissingValuesMetric",
                    field_path=DatasetMissingValuesMetric.fields.current.share_of_missing_values,
                    legend="Missing Values Share",
                ),
            ],
            plot_type=PlotType.LINE,
        )
    )
    project.save()
    return project


def create_demo_project(workspace: str):
    ws = Workspace.create(workspace)
    project_ev = create_project(ws)
    return ws, project_ev
# Out:
# The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.

# %%
ws, project_ev = create_demo_project(WORKSPACE)

# %% [markdown]
# # Deploy

# %%
def deply_serv(image=None, monitoring=True):
    # Import the serving function from the function hub
    serving_fn = import_function(
        "hub://v2_model_server", project=project_name, new_name="serving-3"
    )

    # Add the model to the serving function's routing spec
    serving_fn.add_model(
        model_name, model_path=f"store://models/{project_name}/{model_name}:latest"
    )
    if monitoring:
        tracking_policy = {
            "default_batch_intervals": "0 */2 * * *",
            "stream_image": image,
            "default_batch_image": image,
            "application_batch": True,
        }
        serving_fn.set_tracking(tracking_policy=tracking_policy)

    serving_fn.spec.build.image = image
    serving_fn.spec.image = image
    serving_fn.spec.build.requirements = ["scikit-learn"]

    # Deploy the function
    serving_fn.deploy()
    return serving_fn

# %%
serving_fn = deply_serv(image="davesh0812/mlrun-api:1.5.0")
# Out:
# > 2023-09-06 11:55:40,333 [info] Starting remote function deploy
# 2023-09-06 11:55:41  (info) Deploying function
# 2023-09-06 11:55:41  (info) Building
# 2023-09-06 11:55:41  (info) Staging files and preparing base images
# 2023-09-06 11:55:41  (info) Building processor image

# %% [markdown]
# # Invoke the model

# %%
import json
from time import sleep
from random import choice, uniform

iris = load_iris()
iris_data = iris["data"].tolist()

model_name = "RandomForestClassifier"
serving_1 = project.get_function("serving-3")
0
for i in range(150):
    data_point = choice(iris_data)
    # data_point = [0.5,0.5,0.5,0.5]
    serving_1.invoke(
        f"v2/models/{model_name}/infer", json.dumps({"inputs": [data_point]})
    )
    sleep(choice([0.01, 0.04]))
# Out:
# > 2023-09-06 11:33:27,783 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,199 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,244 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,327 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,410 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,468 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,517 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,561 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,627 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,670 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,736 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,781 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,827 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,879 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:28,953 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,003 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,052 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,123 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,192 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,228 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,267 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,344 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,409 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,475 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,542 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,607 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,643 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,715 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,762 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,804 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,926 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,963 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:29,999 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,039 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,115 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,196 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,234 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,303 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,339 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,406 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,473 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,508 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,572 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,640 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,679 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,747 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,814 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,850 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,885 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,920 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:30,992 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,058 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,124 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,161 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,229 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,275 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,316 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,352 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,418 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,453 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,488 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,554 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,618 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,684 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,755 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,792 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,829 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,894 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:31,933 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,000 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,036 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,080 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,130 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,182 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,248 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,318 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,354 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,422 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,459 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,532 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,575 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,643 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,683 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,722 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,795 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,868 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:32,937 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,125 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,162 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,201 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,269 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,335 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,401 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,467 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,533 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,600 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,675 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,712 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,745 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,809 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,874 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,910 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:33,975 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,010 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,045 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,078 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,112 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,148 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,216 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,267 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,309 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,378 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,414 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,481 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,519 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,584 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,653 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,759 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,810 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,897 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:34,984 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,027 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,071 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,109 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,150 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,187 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,224 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,260 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,296 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,361 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,433 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,505 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,543 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,611 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,681 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,747 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,819 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,856 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,900 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:35,937 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,002 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,040 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,120 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,185 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,221 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,256 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,327 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,367 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,416 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}
# > 2023-09-06 11:33:36,452 [info] invoking function: {'method': 'POST', 'path': 'http://nuclio-new-iris-app-ev-v28-serving-3.default-tenant.svc.cluster.local:8080/v2/models/RandomForestClassifier/infer'}

# %% [markdown]
# # APPLICATION REGISTRATION

# %%
project.set_model_monitoring_application(
    application_class="MyApp",
    requirements=[
        "git+https://github.com/davesh0812/mlrun.git@feature/monitoring-batch-02-evidently",
        "evidently~=0.4.3",
    ],
    name="myApp",
)
# Out:
# > 2023-09-06 11:41:14,432 [warning] Failed to add git metadata, ignore if path is not part of a git repo.: {'path': './', 'error': '/User/DAVID/monitoring'}
# > 2023-09-06 11:41:24,509 [info] Starting remote function deploy
# 2023-09-06 11:41:24  (info) Deploying function
# 2023-09-06 11:41:24  (info) Building
# 2023-09-06 11:41:25  (info) Staging files and preparing base images
# 2023-09-06 11:41:25  (info) Building processor image
# 2023-09-06 11:43:09  (info) Build complete
# 2023-09-06 11:44:45  (info) Function deploy complete
# > 2023-09-06 11:44:48,062 [info] successfully deployed function: {'internal_invocation_urls': ['nuclio-new-iris-app-ev-v28-myapp.default-tenant.svc.cluster.local:8080'], 'external_invocation_urls': ['new-iris-app-ev-v28-myapp-new-iris-app-ev-v28.default-tenant.app.vmdev41.lab.iguazeng.com/']}

# %%
project.set_model_monitoring_application(
    application_class="MyEvidentlyApp",
    requirements=[
        "git+https://github.com/davesh0812/mlrun.git@feature/monitoring-batch-02-evidently",
        "evidently~=0.4.3",
    ],
    name="MyEvidentlyApp",
    evidently_workspace_path=ws.path,
    evidently_project_id=str(project_ev.id),
)
# Out:
# > 2023-09-06 11:44:48,392 [warning] Failed to add git metadata, ignore if path is not part of a git repo.: {'path': './', 'error': '/User/DAVID/monitoring'}
# > 2023-09-06 11:44:57,387 [info] Starting remote function deploy
# 2023-09-06 11:44:57  (info) Deploying function
# 2023-09-06 11:44:57  (info) Building
# 2023-09-06 11:44:57  (info) Staging files and preparing base images
# 2023-09-06 11:44:57  (info) Building processor image
# 2023-09-06 11:52:06  (info) Build complete
# 2023-09-06 11:54:00  (info) Function deploy complete
# > 2023-09-06 11:54:04,864 [info] successfully deployed function: {'internal_invocation_urls': ['nuclio-new-iris-app-ev-v28-myevidentlyapp.default-tenant.svc.cluster.local:8080'], 'external_invocation_urls': ['new-iris-app-ev-v28-myevidentlyapp-new-iris-app-ev-v28.default-tenant.app.vmdev41.lab.iguazeng.com/']}

# %% [markdown]
# # USER APPLICATION CODE

# %%
# mlrun: start-code

# %%
import mlrun
from mlrun.model_monitoring.application import (
    ModelMonitoringApplication,
    ModelMonitoringApplicationResult,
)
from mlrun.model_monitoring.evidently_application import (
    EvidentlyModelMonitoringApplication,
)
from mlrun.datastore.targets import ParquetTarget
import typing
import pandas as pd
import json
from mlrun.artifacts import (
    Artifact,
    DatasetArtifact,
    PlotlyArtifact,
    TableArtifact,
    update_dataset_meta,
)

from sklearn.datasets import load_iris
import datetime

from sklearn import datasets

from evidently.metrics import ColumnDriftMetric
from evidently.metrics import ColumnSummaryMetric
from evidently.metrics import DatasetDriftMetric
from evidently.metrics import DatasetMissingValuesMetric
from evidently.report import Report
from evidently.test_preset import DataDriftTestPreset
from evidently.test_suite import TestSuite
from evidently.ui.dashboards import CounterAgg
from evidently.ui.dashboards import DashboardPanelCounter
from evidently.ui.dashboards import DashboardPanelPlot
from evidently.ui.dashboards import PanelValue
from evidently.ui.dashboards import PlotType
from evidently.ui.dashboards import ReportFilter
from evidently.ui.remote import RemoteWorkspace
from evidently.ui.workspace import Workspace
from evidently.ui.workspace import WorkspaceBase


class MyEvidentlyApp(EvidentlyModelMonitoringApplication):
    def run_application(
        self,
        application_name: str,
        sample_df_stats: pd.DataFrame,
        feature_stats: pd.DataFrame,
        sample_df: pd.DataFrame,
        schedule_time: pd.Timestamp,
        latest_request: pd.Timestamp,
        endpoint_id: str,
        output_stream_uri: str,
    ) -> typing.Union[
        ModelMonitoringApplicationResult, typing.List[ModelMonitoringApplicationResult]
    ]:
        iris = load_iris()
        self.train_set = pd.DataFrame(
            iris["data"],
            columns=[
                "sepal_length_cm",
                "sepal_width_cm",
                "petal_length_cm",
                "petal_width_cm",
            ],
        )

        sample_df = sample_df[
            ["sepal_length_cm", "sepal_width_cm", "petal_length_cm", "petal_width_cm"]
        ]
        print("sample_df_stats.head()")
        print(sample_df_stats.head())
        print("feature_stats.head()")
        print(feature_stats.head())
        print("sample_df.head()")
        print(sample_df.head())
        print("schedule_time")
        print(schedule_time)

        data_drift_report = self.create_report(sample_df, schedule_time)
        self.evidently_workspace.add_report(
            self.evidently_project_id, data_drift_report
        )
        data_drift_test_suite = self.create_test_suite(sample_df, schedule_time)
        self.evidently_workspace.add_test_suite(
            self.evidently_project_id, data_drift_test_suite
        )

        self.log_evidently_object(data_drift_report, f"report_{str(schedule_time)}")
        self.log_evidently_object(data_drift_test_suite, f"suite_{str(schedule_time)}")
        self.log_project_dashboard(None, schedule_time + datetime.timedelta(minutes=1))

        return ModelMonitoringApplicationResult(
            "king-evedintly",
            endpoint_id,
            schedule_time,
            result_name="data_drift_test",
            result_value=0.5,
            result_kind=mlrun.common.schemas.model_monitoring.constants.ResultKindApp.data_drift,
            result_status=mlrun.common.schemas.model_monitoring.constants.ResultStatusApp.detected,
            result_extra_data={},
        )

    def create_report(self, sample_df, schedule_time):
        metrics = [
            DatasetDriftMetric(),
            DatasetMissingValuesMetric(),
        ]
        for col_name in [
            "sepal_length_cm",
            "sepal_width_cm",
            "petal_length_cm",
            "petal_width_cm",
        ]:
            metrics.extend(
                [
                    ColumnDriftMetric(column_name=col_name, stattest="wasserstein"),
                    ColumnSummaryMetric(column_name=col_name),
                ]
            )

        data_drift_report = Report(
            metrics=metrics,
            timestamp=schedule_time,
        )

        data_drift_report.run(reference_data=self.train_set, current_data=sample_df)
        return data_drift_report

    def create_test_suite(self, sample_df, schedule_time):
        data_drift_test_suite = TestSuite(
            tests=[DataDriftTestPreset()],
            timestamp=schedule_time,
        )

        data_drift_test_suite.run(reference_data=self.train_set, current_data=sample_df)
        return data_drift_test_suite

# %%
import mlrun
from mlrun.model_monitoring.application import (
    ModelMonitoringApplication,
    ModelMonitoringApplicationResult,
)
from mlrun.datastore.targets import ParquetTarget
import typing
import pandas as pd
import json
from mlrun.artifacts import (
    Artifact,
    DatasetArtifact,
    PlotlyArtifact,
    TableArtifact,
    update_dataset_meta,
)
import os

from mlrun.artifacts.manager import ArtifactManager, extend_artifact_path

from mlrun.datastore import store_manager


class MyApp(ModelMonitoringApplication):
    def __init__(self):
        self.name = "a"

    def run_application(
        self,
        application_name: str,
        sample_df_stats: pd.DataFrame,
        feature_stats: pd.DataFrame,
        sample_df: pd.DataFrame,
        schedule_time: pd.Timestamp,
        latest_request: pd.Timestamp,
        endpoint_id: str,
        output_stream_uri: str,
    ) -> typing.Union[
        ModelMonitoringApplicationResult, typing.List[ModelMonitoringApplicationResult]
    ]:
        print("sample_df_stats.head()")
        print(sample_df_stats.head())
        print("feature_stats.head()")
        print(feature_stats.head())
        print("sample_df.head()")
        print(sample_df.head())
        print("schedule_time")
        print(schedule_time)

        self.context.log_artifact(TableArtifact("current_stats", df=sample_df_stats))

        return ModelMonitoringApplicationResult(
            self.name,
            endpoint_id,
            schedule_time,
            result_name="data_drift_test",
            result_value=0.5,
            result_kind=mlrun.common.schemas.model_monitoring.constants.ResultKindApp.data_drift,
            result_status=mlrun.common.schemas.model_monitoring.constants.ResultStatusApp.detected,
            result_extra_data={},
        )

# %%
# mlrun: end-code
